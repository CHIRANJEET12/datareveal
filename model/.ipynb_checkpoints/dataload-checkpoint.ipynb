# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("../csv/Mall_Customers.csv")

# %%
df.head(), df.shape
# Out:
# (   CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
#  0           1    Male   19                  15                      39
#  1           2    Male   21                  15                      81
#  2           3  Female   20                  16                       6
#  3           4  Female   23                  16                      77
#  4           5  Female   31                  17                      40,
#  (200, 5))

# %%
# df1 = pd.read_csv("csv/wine_data.csv")

# %%
# df1.head()

# %%
df
# Out:
#      CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]

# %%
def remid(df):
    m = df.columns[0]
    l = list(df.columns[0])
    l.reverse()
    s = ""
    for i in l:
        s+=i
        if s[:2].upper()=='DI':
            if m in df.columns:          
                df.drop(columns=[m], inplace=True)
                print(f"Dropped column: {m}")
            else:
                print(f"Column {m} not found, cannot drop.")
        else:
            print(f"Column {m} does not end with ID, not dropped.")

    return df

# %%
remid(df)
# Out:
# Column CustomerID does not end with ID, not dropped.
# Dropped column: CustomerID
# Column CustomerID not found, cannot drop.
# Column CustomerID not found, cannot drop.
# Column CustomerID not found, cannot drop.
# Column CustomerID not found, cannot drop.
# Column CustomerID not found, cannot drop.
# Column CustomerID not found, cannot drop.
# Column CustomerID not found, cannot drop.
# Column CustomerID not found, cannot drop.
#       Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0      Male   19                  15                      39
# 1      Male   21                  15                      81
# 2    Female   20                  16                       6
# 3    Female   23                  16                      77
# 4    Female   31                  17                      40
# ..      ...  ...                 ...                     ...
# 195  Female   35                 120                      79
# 196  Female   45                 126                      28
# 197    Male   32                 126                      74
# 198    Male   32                 137                      18
# 199    Male   30                 137                      83
#
# [200 rows x 4 columns]

# %%
df.isnull().sum()
# Out:
# Genre                     0
# Age                       0
# Annual Income (k$)        0
# Spending Score (1-100)    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
numeric_df = df.select_dtypes(include=['int64','float64'])
numeric_df.corr()
# Out:
#                              Age  Annual Income (k$)  Spending Score (1-100)
# Age                     1.000000           -0.012398               -0.327227
# Annual Income (k$)     -0.012398            1.000000                0.009903
# Spending Score (1-100) -0.327227            0.009903                1.000000

# %%
df.describe()
# Out:
#               Age  Annual Income (k$)  Spending Score (1-100)
# count  200.000000          200.000000              200.000000
# mean    38.850000           60.560000               50.200000
# std     13.969007           26.264721               25.823522
# min     18.000000           15.000000                1.000000
# 25%     28.750000           41.500000               34.750000
# 50%     36.000000           61.500000               50.000000
# 75%     49.000000           78.000000               73.000000
# max     70.000000          137.000000               99.000000

# %%
df.dtypes
# Out:
# Genre                     object
# Age                        int64
# Annual Income (k$)         int64
# Spending Score (1-100)     int64
# dtype: object

# %%
sns.heatmap(numeric_df.corr())
plt.show()

# %%
def dataunderstand(df):
    print("📊 Indepth Understanding of the dataset\n")
    
    print("1️⃣ First 5 rows:")
    print(df.head(), "\n")
    
    print("2️⃣ Dataset shape (rows, columns):")
    print(df.shape, "\n")
    
    print("3️⃣ Missing values in each column:")
    print(df.isnull().sum(), "\n")
    
    print("4️⃣ Number of duplicate rows:")
    print(df.duplicated().sum(), "\n")
    
    print("5️⃣ Statistical summary of numeric columns:")
    print(df.describe(), "\n")

    print("5️⃣ Correlation:")
    numeric_df = df.select_dtypes(include=['int64','float64'])
    numeric_df.corr()
    
    print("5️⃣ Heatmap:")
    sns.heatmap(numeric_df.corr())
    plt.show()

    print("5️⃣ Check for Outliers:")
    plt.figure(figsize=(10,6))
    plt.boxplot(numeric_df)
    plt.show()

    print("5️⃣ Histplot:")
    for c in numeric_df.columns:
        plt.figure(figsize=(13,8))
        sns.histplot(numeric_df[c], kde=True)

# %%
dataunderstand(df)
# Out:
# 📊 Indepth Understanding of the dataset
#
# 1️⃣ First 5 rows:
#     Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0    Male   19                  15                      39
# 1    Male   21                  15                      81
# 2  Female   20                  16                       6
# 3  Female   23                  16                      77
# 4  Female   31                  17                      40
#
# 2️⃣ Dataset shape (rows, columns):
# (200, 4)
#
# 3️⃣ Missing values in each column:
# Genre                     0
# Age                       0
# Annual Income (k$)        0
# Spending Score (1-100)    0
# dtype: int64
#
# 4️⃣ Number of duplicate rows:
# 0
#
# 5️⃣ Statistical summary of numeric columns:
#               Age  Annual Income (k$)  Spending Score (1-100)
# count  200.000000          200.000000              200.000000
# mean    38.850000           60.560000               50.200000
# std     13.969007           26.264721               25.823522
# min     18.000000           15.000000                1.000000
# 25%     28.750000           41.500000               34.750000
# 50%     36.000000           61.500000               50.000000
# 75%     49.000000           78.000000               73.000000
# max     70.000000          137.000000               99.000000
#
# 5️⃣ Correlation:
# 5️⃣ Heatmap:
# 5️⃣ Check for Outliers:
# 5️⃣ Histplot:

# %%
df.dropna()
# Out:
#       Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0      Male   19                  15                      39
# 1      Male   21                  15                      81
# 2    Female   20                  16                       6
# 3    Female   23                  16                      77
# 4    Female   31                  17                      40
# ..      ...  ...                 ...                     ...
# 195  Female   35                 120                      79
# 196  Female   45                 126                      28
# 197    Male   32                 126                      74
# 198    Male   32                 137                      18
# 199    Male   30                 137                      83
#
# [200 rows x 4 columns]

# %%
df.replace("null", np.nan, inplace=True)
